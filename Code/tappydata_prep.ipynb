# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
from pandas.errors import EmptyDataError
import os
from functools import partial
import re
from collections import Counter
from scipy.stats import skew, kurtosis

from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import cross_validate, cross_val_score, train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone, BaseEstimator, TransformerMixin

# Set plot style
plt.rcParams['figure.figsize'] = (10, 6)
style.use('ggplot')

# Update these paths
user_root = r"..\data\Archived-users\Archived users"
keys_root = r"..\data\Archived-Data\Tappy Data"

# Read user files
def read_one_file(fn, root):
    out = dict()
    with open(os.path.join(root, fn), 'r', encoding='utf-8') as f:
        for line in f.readlines():
            if ": " in line:
                k, v = line.split(": ")
                out[k] = v.strip()
        out['ID'] = re.findall(r'_(\w+)\.', fn)[0]
    return out

user_fn_list = os.listdir(user_root)
users_list = list(map(partial(read_one_file, root=user_root), user_fn_list))
users = pd.DataFrame(users_list)
users.replace(['------', ''], np.nan, inplace=True)

# Convert boolean columns
bool_cols = ['Levadopa', 'MAOB', 'Parkinsons', 'Tremors', 'Other']
for col in bool_cols:
    users[col] = users[col] == 'True'

# Read keypress files
def read_one_key_file(fn, root):
    try:
        # Read the file
        df = pd.read_csv(os.path.join(root, fn), delimiter='\t', header=None, on_bad_lines='skip', low_memory=False)

        # Drop the last column if the file has 9 columns (since the last col is NaN)
        if df.shape[1] == 9:
            df = df.iloc[:, :-1]

        # Ensure the DataFrame has exactly 8 columns
        if df.shape[1] != 8:
            print(f"Skipping file {fn} due to incorrect number of columns")
            return pd.DataFrame()

        # Assign column names
        df.columns = ['ID', 'Date', 'TS', 'Hand', 'HoldTime', 'Direction', 'LatencyTime', 'FlightTime']

        # Convert columns with known types
        df['ID'] = df['ID'].astype(str)
        df['Date'] = df['Date'].astype(str)
        df['TS'] = df['TS'].astype(str)
        df['Hand'] = df['Hand'].astype(str)
        df['Direction'] = df['Direction'].astype(str)

        # Convert numeric columns safely
        for col in ['HoldTime', 'LatencyTime', 'FlightTime']:
            df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to float, setting errors to NaN

        return df.dropna(subset=['HoldTime', 'LatencyTime', 'FlightTime'])  # Drop rows with NaNs in numeric cols

    except Exception as e:
        print(f"Error reading {fn}: {e}")
        return pd.DataFrame()

# Read all keypress files
keys_fn_list = os.listdir(keys_root)
keys_list = list(map(partial(read_one_key_file, root=keys_root), keys_fn_list))

# Concatenate all keypress data
keys = pd.concat(keys_list, ignore_index=True, axis=0)

# Print dataset stats
print("Total user IDs in key logs:", len(set(keys['ID'].unique())))
print("Total user IDs in user info:", len(set(users['ID'].unique())))

# Get valid users
user_w_sufficient_data = set(keys.groupby('ID').size()[keys.groupby('ID').size() >= 2000].index)
user_eligible = set(users[((users['Parkinsons']) & (users.get('Impact', pd.Series()) == 'Mild')) 
                           | (~users['Parkinsons']) & (~users['Levadopa'])]['ID'])
user_valid = user_w_sufficient_data.intersection(user_eligible)

# Filter valid keypress data
valid_keys = keys[(keys['HoldTime'] > 0) & (keys['LatencyTime'] > 0) 
                   & (keys['HoldTime'] < 2000) & (keys['LatencyTime'] < 2000)
                   & keys['ID'].isin(user_valid)]

# Aggregate features
hold_by_user = valid_keys[valid_keys['Hand'] != 'S'].groupby(['ID', 'Hand'])['HoldTime'].agg([np.mean, np.std, skew, kurtosis])
latency_by_user = valid_keys[valid_keys['Direction'].isin(['LL', 'LR', 'RL', 'RR'])].groupby(['ID', 'Direction'])['LatencyTime'].agg([np.mean, np.std, skew, kurtosis])

# Reshape data
hold_by_user_flat = hold_by_user.unstack()
hold_by_user_flat.columns = ['_'.join(col).strip() for col in hold_by_user_flat.columns.values]
hold_by_user_flat['mean_hold_diff'] = hold_by_user_flat['mean_L'] - hold_by_user_flat['mean_R']

latency_by_user_flat = latency_by_user.unstack()
latency_by_user_flat.columns = ['_'.join(col).strip() for col in latency_by_user_flat.columns.values]
latency_by_user_flat['mean_LR_RL_diff'] = latency_by_user_flat['mean_LR'] - latency_by_user_flat['mean_RL']
latency_by_user_flat['mean_LL_RR_diff'] = latency_by_user_flat['mean_LL'] - latency_by_user_flat['mean_RR']

# Combine datasets
combined = pd.concat([hold_by_user_flat, latency_by_user_flat], axis=1)

# Merge with user labels
full_set = pd.merge(combined.reset_index(), users[['ID', 'Parkinsons']], on='ID')
full_set.set_index('ID', inplace=True)
full_set.dropna(inplace=True)  # Remove rows with NaN values

# Save dataset for download
output_path = "../data/full_set.csv"
full_set.to_csv(output_path)

print(f"Dataset saved successfully as {output_path}")
print("Final dataset shape:", full_set.shape)
print(full_set.head())
# Out:
# Skipping file TBOPVHGLMX_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file MG8XVA5BFA_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file ZQ4UHHUPNZ_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file BFXNVL50DC_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file 9JRHCGCWAZ_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file YNESMGNGWK_1606.txtZone.Identifier due to incorrect number of columns
# Skipping file 8MERXVINPN_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file RDJPGMWKAG_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file YAJFHG6OHD_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file HSOCXZDCZM_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file 1HOEBIGASW_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file G6OE5CXQPY_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file ZWBPPNQCUX_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file M6MUS5WY6N_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file FIWPKLWCT5_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file MQ6HDDONF0_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file ITWTZ5F3VW_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file NMMGWRY6SO_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file LA6KW35OXK_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file 6LB9FQABZQ_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file STW9PUPHWN_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file LA6KW35OXK_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file LIPRETG9WY_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file GUDRVXO6RX_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file 6LB9FQABZQ_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file GRPUBQLE4F_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file ZY9CCHSPF2_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file U8RI3K0CGP_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file QEYMRM1ZSM_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file JHBOKKHOQW_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file EX8J9DGRSY_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file FIWPKLWCT5_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file FIWPKLWCT5_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file SWJ4Q9V1NW_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file LKR3NUMIFS_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file SPNOI40JCA_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file QCFNDCZPQH_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file YI43UM1CEH_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file YI43UM1CEH_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file IDZHIUK2W2_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file CAXCJIKLYM_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file PRG54RZY7X_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file R3OKI24Z0Q_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file ZGZJSOXBWP_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file ZY9CCHSPF2_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file QAH9IVALVC_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file F56FSV2EP7_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file EF9XEFXPBN_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file RDJHNZGQL2_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file 6R9IGYWVWT_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file SDZPQV3VZ1_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file WBS5I7VF1G_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file VVYPNRQ5KG_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file ICXFP2WKAU_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file B4NL4SV9ZC_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file GRPUBQLE4F_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file NPACI6EW26_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file JWGIQXYUDJ_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file PVADT62JUM_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file 6WBXSDG5BB_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file JHBOKKHOQW_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file WHUETYQCMK_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file ZY9CCHSPF2_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file TBOPVHGLMX_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file ZQ4UHHUPNZ_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file IDYIDJBAXF_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file AFQWSP8ARK_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file PRGWGP1WH4_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file JQ0YSY0AYO_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file AVNGRDUXE5_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file FFNMFHHSZJ_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file S0YGDLIF9V_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file AJHHNPKG0K_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file YQSGN9BMVK_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file ITWTZ5F3VW_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file MFAQFDW3IH_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file 3DIXPRIOSW_1702.txtZone.Identifier due to incorrect number of columns
# Skipping
txtZone.Identifier due to incorrect number of columns
# Skipping file ZQ4UHHUPNZ_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file ZI1KGKLCD5_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file SPNOI40JCA_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file KE21ILBSOI_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file E1E2I8HUGC_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file 8O9IAIA9L1_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file VVYPNRQ5KG_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file COK8G1W7JY_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file YI43UM1CEH_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file BENXJNDSC4_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file P8HEQZSYJN_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file NCHCW5MTBJ_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file EMYGMAIB2L_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file X7PEJ5EG77_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file AXXXXBBCCH_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file 2JTCBKUP8T_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file 927ZLCPEJM_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file R8CJDKFQJZ_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file GHRLW1IJRV_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file 7XS9VOLXWU_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file 7HTEQAAWWO_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file HB2JCE24IE_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file YIA9DW5AGQ_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file CAXCJIKLYM_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file BFXNVL50DC_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file 5PQVTWULAC_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file WBS5I7VF1G_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file ZQ4UHHUPNZ_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file 8EY6NZAKCI_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file 48DZPAJ5NS_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file VR0LFE1JUC_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file CAXCJIKLYM_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file UDCY90VKYN_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file WDNE1Q9EHT_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file XWAX2IHF3O_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file F8KU8UP2SZ_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file IDYIDJBAXF_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file MG8XVA5BFA_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file S0YGDLIF9V_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file TBOPVHGLMX_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file PRGWGP1WH4_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file AFNOZ1KI1M_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file LA6KW35OXK_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file TL2XHTLK1T_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file TL2XHTLK1T_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file YQSGN9BMVK_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file 39KQRZCESF_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file UH6FQWXIZI_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file 5ARV4LHEJ0_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file R3OKI24Z0Q_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file EKG57AN0N6_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file 1XNJCXS3EY_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file EX8J9DGRSY_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file ZWBPPNQCUX_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file 3MZWDTW7CC_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file QAH9IVALVC_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file UFMGBC58XD_1607.txtZone.Identifier due to incorrect number of columns
# Skipping file ZIUU38ZJXA_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file QDV7XQWLI7_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file HB2JCE24IE_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file NPACI6EW26_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file ZY9CCHSPF2_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file JHBOKKHOQW_1612.txtZone.Identifier due to incorrect number of columns
# Skipping file 0NMZ9JBBHI_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file F8KU8UP2SZ_1702.txtZone.Identifier due to incorrect number of columns
# Skipping file NPACI6EW26_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file C6UGS6P0J0_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file 0NMZ9JBBHI_1608.txtZone.Identifier due to incorrect number of columns
# Skipping file PRGWGP1WH4_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file OMCPRWYBSQ_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file 8TEUUGQBYB_1611.txtZone.Identifier due to incorrect number of columns
# Skipping file JMIVIRFQRR_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file ARUGT4UL2R_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file LKR3NUMIFS_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file PRGWGP1WH4_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file LKR3NUMIFS_1610.txtZone.Identifier due to incorrect number of columns
# Skipping file SH6ZX4UKRO_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file L9ULZGDITG_1609.txtZone.Identifier due to incorrect number of columns
# Skipping file SKLXBAOSN4_1703.txtZone.Identifier due to incorrect number of columns
# Skipping file TAGYMXUFJE_1701.txtZone.Identifier due to incorrect number of columns
# Skipping file ZQ4UHHUPNZ_1702.txtZone.Identifier due to incorrect number of columns
# Total user IDs in key logs: 333
# Total user IDs in user info: 227
# C:\Users\vyrus\AppData\Local\Temp\ipykernel_10400\2008195018.py:107: FutureWarning: The provided callable <function mean at 0x0000029A219D6A20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hold_by_user = valid_keys[valid_keys['Hand'] != 'S'].groupby(['ID', 'Hand'])['HoldTime'].agg([np.mean, np.std, skew, kurtosis])
# C:\Users\vyrus\AppData\Local\Temp\ipykernel_10400\2008195018.py:107: FutureWarning: The provided callable <function std at 0x0000029A219D6C00> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   hold_by_user = valid_keys[valid_keys['Hand'] != 'S'].groupby(['ID', 'Hand'])['HoldTime'].agg([np.mean, np.std, skew, kurtosis])
# C:\Users\vyrus\AppData\Local\Temp\ipykernel_10400\2008195018.py:108: FutureWarning: The provided callable <function mean at 0x0000029A219D6A20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   latency_by_user = valid_keys[valid_keys['Direction'].isin(['LL', 'LR', 'RL', 'RR'])].groupby(['ID', 'Direction'])['LatencyTime'].agg([np.mean, np.std, skew, kurtosis])
# C:\Users\vyrus\AppData\Local\Temp\ipykernel_10400\2008195018.py:108: FutureWarning: The provided callable <function std at 0x0000029A219D6C00> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   latency_by_user = valid_keys[valid_keys['Direction'].isin(['LL', 'LR', 'RL', 'RR'])].groupby(['ID', 'Direction'])['LatencyTime'].agg([np.mean, np.std, skew, kurtosis])
# Dataset saved successfully as full_set.csv
# Final dataset shape: (262, 28)
#                 mean_L      mean_R      std_L      std_R    skew_L    skew_R  \
# ID
# 0EA27ICBLF   77.749454   79.306669  17.598336  24.609195  1.585104  4.130272
# 0EA27ICBLF   77.749454   79.306669  17.598336  24.609195  1.585104  4.130272
# 2JTCBKUP8T   89.355483   90.890535  22.041569  34.355843  0.795678  0.507986
# 2JTCBKUP8T   89.355483   90.890535  22.041569  34.355843  0.795678  0.507986
# 310NXPGJPD  153.521655  149.722970  43.931450  37.167793  1.351041  1.150740
#
#             kurtosis_L  kurtosis_R  mean_hold_diff     mean_LL  ...   skew_LR  \
# ID                                                              ...
# 0EA27ICBLF   11.521208   44.939249       -1.557215  263.580311  ...  0.884186
# 0EA27ICBLF   11.521208   44.939249       -1.557215  263.580311  ...  0.884186
# 2JTCBKUP8T    7.205031    2.213135       -1.535052  316.334084  ...  0.220483
# 2JTCBKUP8T    7.205031    2.213135       -1.535052  316.334084  ...  0.220483
# 310NXPGJPD    2.606522    1.740574        3.798685  489.852888  ... -0.854579
#
#              skew_RL   skew_RR  kurtosis_LL  kurtosis_LR  kurtosis_RL  \
# ID
# 0EA27ICBLF -1.188579  0.148528    -0.700351    -0.290392     2.160455
# 0EA27ICBLF -1.188579  0.148528    -0.700351    -0.290392     2.160455
# 2JTCBKUP8T  0.605639  0.476038     1.246125    -0.675195    -0.876806
# 2JTCBKUP8T  0.605639  0.476038     1.246125    -0.675195    -0.876806
# 310NXPGJPD -0.050837  0.139720    -1.015394    -0.438153    -0.423111
#
#             kurtosis_RR  mean_LR_RL_diff  mean_LL_RR_diff  Parkinsons
# ID
# 0EA27ICBLF    -1.237978      -139.245790       -10.284312       False
# 0EA27ICBLF    -1.237978      -139.245790       -10.284312        True
# 2JTCBKUP8T    -0.016502        39.519115       -21.948033        True
# 2JTCBKUP8T    -0.016502        39.519115       -21.948033       False
# 310NXPGJPD    -1.052716        30.863529         0.345793        True
#
# [5 rows x 28 columns]
